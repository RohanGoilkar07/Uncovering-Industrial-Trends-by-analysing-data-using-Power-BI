# %%
import pandas as pd

# %%
df = pd.read_csv("Dataset.csv", encoding='unicode_escape', low_memory=False)
df
# Out:
#                  ID  Unit  Gender  Product    Category Segment    Store  \
# 0      2.080450e+11     1    Male  Kaizala  Office 365    Cyan     Fama
# 1      3.147980e+11     1    Male  Kaizala  Office 365    Cyan  Contoso
# 2      2.789790e+11     1    Male  Kaizala  Office 365    Cyan  Contoso
# 3      4.342780e+12     1    Male  Kaizala  Office 365    Cyan    Pomum
# 4      4.596440e+12     1    Male  Kaizala  Office 365    Cyan  Contoso
# ...             ...   ...     ...      ...         ...     ...      ...
# 29870  2.792940e+14     2    Male    Excel  Office 365    Jade  Contoso
# 29871  2.732170e+14     2    Male    Excel  Office 365    Jade      Leo
# 29872  2.717690e+14     2    Male    Excel  Office 365    Jade   Natura
# 29873  2.724450e+14     2    Male    Excel  Office 365    Jade  Contoso
# 29874  2.768690e+14     2  Female    Excel  Office 365    Jade    Pomum
#
#            Type Issue Promotion  ...  \
# 0      Internal  None      None  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29875 entries, 0 to 29874
# Data columns (total 64 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               29875 non-null  float64
#  1   Unit             29875 non-null  int64
#  2   Gender           29875 non-null  object
#  3   Product          29875 non-null  object
#  4   Category         29875 non-null  object
#  5   Segment          29875 non-null  object
#  6   Store            29875 non-null  object
#  7   Type             29875 non-null  object
#  8   Issue            29875 non-null  object
#  9   Promotion        29875 non-null  object
#  10  Amount           29875 non-null  object
#  11  Age              29875 non-null  object
#  12  Price Range      29875 non-null  object
#  13  ProductID        24 non-null     float64
#  14  Product Image    24 non-null     object
#  15  Product.1        24 non-null     object
# ...

# %%
        
df.drop(df.iloc[:, 13:63], inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29875 entries, 0 to 29874
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           29875 non-null  float64
#  1   Unit         29875 non-null  int64
#  2   Gender       29875 non-null  object
#  3   Product      29875 non-null  object
#  4   Category     29875 non-null  object
#  5   Segment      29875 non-null  object
#  6   Store        29875 non-null  object
#  7   Type         29875 non-null  object
#  8   Issue        29875 non-null  object
#  9   Promotion    29875 non-null  object
#  10  Amount       29875 non-null  object
#  11  Age          29875 non-null  object
#  12  Price Range  29875 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 3.0+ MB
